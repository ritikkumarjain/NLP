# %%
import pandas as pd

# %%
text = pd.read_csv('train_as.txt',header=None, error_bad_lines=False)
# Out:
# b'Skipping line 7: expected 1 fields, saw 4\nSkipping line 8: expected 1 fields, saw 2\nSkipping line 11: expected 1 fields, saw 3\nSkipping line 13: expected 1 fields, saw 2\nSkipping line 14: expected 1 fields, saw 3\nSkipping line 21: expected 1 fields, saw 2\nSkipping line 23: expected 1 fields, saw 4\nSkipping line 26: expected 1 fields, saw 2\nSkipping line 27: expected 1 fields, saw 2\nSkipping line 31: expected 1 fields, saw 2\nSkipping line 33: expected 1 fields, saw 2\nSkipping line 39: expected 1 fields, saw 2\nSkipping line 42: expected 1 fields, saw 2\nSkipping line 46: expected 1 fields, saw 4\nSkipping line 54: expected 1 fields, saw 3\nSkipping line 64: expected 1 fields, saw 6\nSkipping line 83: expected 1 fields, saw 2\nSkipping line 93: expected 1 fields, saw 2\nSkipping line 99: expected 1 fields, saw 3\nSkipping line 100: expected 1 fields, saw 3\nSkipping line 107: expected 1 fields, saw 2\nSkipping line 125: expected 1 fields, saw 3\nSkipping line 136: expected
# ...

# %%
text.columns=['Assamese Text']

# %%
en=pd.read_csv('English sent.csv')

# %%
text['Sentiments']=en['sent']

# %%
text.head()
# Out:
#                                        Assamese Text Sentiments
# 0  কিছুমান ইস্ৰায়েলে কেনে ধৰণৰ অন্যায়পূৰ্ণ কাৰ্য্...   Negative
# 1  বৰ্তমান পশ্চিম বংগৰ বিজেপিৰ মহাসচিব হিচাপে কাৰ...    Neutral
# 2            নতুন ফোল্ডাৰ `%s' নিৰ্মাণ কৰা সম্ভব নহয়    Neutral
# 3  তাৰবাবে আমাৰ দেশৰ যুবশক্তিক আমি চাকৰি প্ৰত্যাশ...    Neutral
# 4                                       মই ইয়াত আছো!    Neutral

# %%
text.to_csv('Assamese Sentiments.csv',index=False)

# %%
text['Sentiments'].value_counts()
# Out:
# Neutral     74730
# Positive    32844
# Negative    13347
# Name: Sentiments, dtype: int64
